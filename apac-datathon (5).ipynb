# %%
import pandas as pd
cold_storage_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Meat_Stats_Cold_Storage.csv')
cold_storage_df.head()
# Out:
#        Date  Year  Month            Unit Animal  Weight Type_Of_Meat
# 0  Dec-2023  2023     12  Million Pounds   Beef  457.41     Red Meat
# 1  Nov-2023  2023     11  Million Pounds   Beef  445.67     Red Meat
# 2  Oct-2023  2023     10  Million Pounds   Beef  420.85     Red Meat
# 3  Sep-2023  2023      9  Million Pounds   Beef  395.40     Red Meat
# 4  Aug-2023  2023      8  Million Pounds   Beef  410.46     Red Meat

# %%
cold_storage_df['Type_Of_Meat'].unique()
# Out:
# array(['Red Meat', 'Poultry'], dtype=object)

# %%
print(cold_storage_df['Date'].min()) # range
print(cold_storage_df['Date'].max())
print(cold_storage_df.shape)
# Out:
# Apr-1983
# Sep-2023
# (3936, 7)

# %%
meat_prod_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Meat_Stats_Meat_Production.csv')
meat_prod_df.head()
# Out:
#        Date  Year  Month            Unit Production Animal  \
# 0  Dec-2023  2023     12  Million Pounds   2,189.80   Beef
# 1  Nov-2023  2023     11  Million Pounds   2,280.90   Beef
# 2  Oct-2023  2023     10  Million Pounds   2,340.90   Beef
# 3  Sep-2023  2023      9  Million Pounds   2,149.40   Beef
# 4  Aug-2023  2023      8  Million Pounds   2,363.50   Beef
#
#   Commercial or Federally Inspected Type of Meat
# 0                        Commercial     Red Meat
# 1                        Commercial     Red Meat
# 2                        Commercial     Red Meat
# 3                        Commercial     Red Meat
# 4                        Commercial     Red Meat

# %%
print(meat_prod_df['Date'].min()) # range
print(meat_prod_df['Date'].max())
print(meat_prod_df.shape)
# Out:
# Apr-1921
# Sep-2023
# (13595, 8)

# %%
meat_prod_df.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Unit', 'Production', 'Animal',
#        'Commercial or Federally Inspected', 'Type of Meat'],
#       dtype='object')

# %%
sl_count_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Meat_Stats_Slaughter_Counts.csv')
sl_count_df.head()
# Out:
#        Date  Year  Month        Unit  Animal     Count  \
# 0  Dec-2023  2023     12  1,000 Head  Cattle  2,593.40
# 1  Nov-2023  2023     11  1,000 Head  Cattle  2,729.90
# 2  Oct-2023  2023     10  1,000 Head  Cattle  2,826.00
# 3  Sep-2023  2023      9  1,000 Head  Cattle  2,610.60
# 4  Aug-2023  2023      8  1,000 Head  Cattle  2,890.00
#
#   Commercial_Or_Federally_Inspected Type_Of_Meat
# 0                        Commercial     Red Meat
# 1                        Commercial     Red Meat
# 2                        Commercial     Red Meat
# 3                        Commercial     Red Meat
# 4                        Commercial     Red Meat

# %%
sl_weights_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Meat_Stats_Slaughter_Weights.csv')
sl_weights_df.head()
# Out:
#        Date  Year  Month                      Unit  Animal    Weight  \
# 0  Dec-2023  2023     12  Average Weight in Pounds  Cattle  1,401.00
# 1  Nov-2023  2023     11  Average Weight in Pounds  Cattle  1,387.00
# 2  Oct-2023  2023     10  Average Weight in Pounds  Cattle  1,374.00
# 3  Sep-2023  2023      9  Average Weight in Pounds  Cattle  1,362.00
# 4  Aug-2023  2023      8  Average Weight in Pounds  Cattle  1,350.00
#
#   Commercial_Or_Federally_Inspected Live_Or_Dressed Type_Of_Meat
# 0                        Commercial            Live     Red Meat
# 1                        Commercial            Live     Red Meat
# 2                        Commercial            Live     Red Meat
# 3                        Commercial            Live     Red Meat
# 4                        Commercial            Live     Red Meat

# %%
obesity_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Nutrition_Physical_Activity_and_Obesity_Data.csv')
obesity_df.head()
# Out:
# /tmp/ipykernel_33/2607019301.py:1: DtypeWarning: Columns (18,19,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   obesity_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/Nutrition_Physical_Activity_and_Obesity_Data.csv')
#    YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0       2019     2019           AK                Alaska
# 1       2019     2019           AZ               Arizona
# 2       2019     2019           DC  District of Columbia
# 3       2019     2019           IL              Illinois
# 4       2019     2019           MD              Maryland
#
#                                 Datasource                    Class  \
# 0  Youth Risk Behavior Surveillance System        Physical Activity
# 1  Youth Risk Behavior Surveillance System  Obesity / Weight Status
# 2  Youth Risk Behavior Surveillance System  Obesity / Weight Status
# 3  Youth Risk Behavior Surveillance System        Physical Activity
# ...

# %%
obesity_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Grade',
#        'Income', 'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID',
#        'QuestionID', 'DataValueTypeID', 'LocationID',
#        'StratificationCategory1', 'Stratification1',
#        'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
print(len(obesity_df['Question'].unique()))
print(obesity_df['Question'].unique()) #categorical column
# Out:
# 17
# ['Percent of students in grades 9-12 who achieve 1 hour or more of moderate-and/or vigorous-intensity physical activity daily'
#  'Percent of students in grades 9-12 who have obesity'
#  'Percent of students in grades 9-12 who participate in daily physical education'
#  'Percent of students in grades 9-12 who have an overweight classification'
#  'Percent of students in grades 9-12 who drank regular soda/pop at least one time per day'
#  'Percent of students in grades 9-12 who consume vegetables less than 1 time daily'
#  'Percent of students in grades 9-12 who consume fruit less than 1 time daily'
#  'Percent of students in grades 9-12 watching 3 or more hours of television each school day'
#  'Percent of adults who engage in no leisure-time physical activity'
#  'Percent of adults aged 18 years and older who have obesity'
#  'Percent of adults aged 18 years and older who have an overweight classification'
# ...

# %%
print((obesity_df['Data_Value'] != obesity_df['Data_Value_Alt']).sum())
# Out:
# 19871

# %%
obesity_df[obesity_df['Data_Value'] != obesity_df['Data_Value_Alt']][['Data_Value', 'Data_Value_Alt']].head(50)
# Out:
#      Data_Value  Data_Value_Alt
# 19          NaN             NaN
# 59          NaN             NaN
# 150         NaN             NaN
# 156         NaN             NaN
# 160         NaN             NaN
# 205         NaN             NaN
# 246         NaN             NaN
# 251         NaN             NaN
# 253         NaN             NaN
# 256         NaN             NaN
# 259         NaN             NaN
# 270         NaN             NaN
# 275         NaN             NaN
# 278         NaN             NaN
# 284         NaN             NaN
# 285         NaN             NaN
# 289         NaN             NaN
# 296         NaN             NaN
# 298         NaN             NaN
# 302         NaN             NaN
# 304         NaN             NaN
# 314         NaN             NaN
# 316         NaN             NaN
# 320         NaN             NaN
# 323         NaN             NaN
# 328         NaN             NaN
# 333         NaN             NaN
# 344         NaN             NaN
# ...

# %%
obesity_df['Data_Value_Unit'].unique()
# Out:
# array([nan])

# %% [markdown]
# ### Removal of redundant features from obesity dataset

# %%
import numpy as np

# %%
obesity_df['Data_Value_Type'].unique()
# Out:
# array(['Value'], dtype=object)

# %%
obesity_df['Income'].value_counts() #valuable column -> keep it
# Out:
# Income
# $50,000 - $74,999     3330
# Data not reported     3330
# Less than $15,000     3330
# $25,000 - $34,999     3330
# $15,000 - $24,999     3330
# $35,000 - $49,999     3330
# $75,000 or greater    3330
# Name: count, dtype: int64

# %%
obesity_df.drop(columns = ['Data_Value_Alt','Class','ClassID','Datasource','Data_Value_Unit', 'YearEnd','LocationAbbr','Data_Value_Type', 'DataValueTypeID', 'Data_Value_Footnote_Symbol'], inplace=True)

# %%
obesity_df.drop(columns = ['StratificationCategory1', 'Stratification1', 'StratificationCategoryId1', 'StratificationID1'], inplace=True)

# %%
obesity_df.head()
# Out:
#    YearStart          LocationDesc                         Topic  \
# 0       2019                Alaska  Physical Activity - Behavior
# 1       2019               Arizona       Obesity / Weight Status
# 2       2019  District of Columbia       Obesity / Weight Status
# 3       2019              Illinois  Physical Activity - Behavior
# 4       2019              Maryland       Obesity / Weight Status
#
#                                             Question  Data_Value  \
# 0  Percent of students in grades 9-12 who achieve...         9.6
# 1  Percent of students in grades 9-12 who have ob...        13.3
# 2  Percent of students in grades 9-12 who have ob...        17.1
# 3  Percent of students in grades 9-12 who partici...        65.9
# 4  Percent of students in grades 9-12 who have an...        16.7
#
#   Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 NaN                   5.5                   16.5
# ...

# %%
unique_questions = obesity_df[['Question', 'QuestionID']].drop_duplicates()
question_id_mapping = unique_questions.set_index('Question')['QuestionID'].to_dict()
question_id_mapping
#obesity/unhealthy lifestyle related hypothesis interested in: Q047,  Q036, Q037, Q018, Q019
#obesity: 'Q038', 'Q039', 'Q036','Q037'
# Out:
# {'Percent of students in grades 9-12 who achieve 1 hour or more of moderate-and/or vigorous-intensity physical activity daily': 'Q048',
#  'Percent of students in grades 9-12 who have obesity': 'Q038',
#  'Percent of students in grades 9-12 who participate in daily physical education': 'Q049',
#  'Percent of students in grades 9-12 who have an overweight classification': 'Q039',
#  'Percent of students in grades 9-12 who drank regular soda/pop at least one time per day': 'Q058',
#  'Percent of students in grades 9-12 who consume vegetables less than 1 time daily': 'Q021',
#  'Percent of students in grades 9-12 who consume fruit less than 1 time daily': 'Q020',
#  'Percent of students in grades 9-12 watching 3 or more hours of television each school day': 'Q059',
#  'Percent of adults who engage in no leisure-time physical activity': 'Q047',
#  'Percent of adults aged 18 years and older who have obesity': 'Q036',
# ...

# %% [markdown]
# ## Hypothesis Test: There exists NO correlation between the income of an adult and an unhealthy lifestyle.
# <p> Unhealthy lifestyle determined by lack of exercise, obesity/overweight, and food consumption patterns (eg. eating fruits/veg less than once daily)</p>

# %%
question_ids = ['Q047', 'Q036', 'Q037', 'Q018', 'Q019']
obesity_related_df = obesity_df[obesity_df['QuestionID'].isin(question_ids)]
obesity_related_df['Income'].isna().sum()
# Out:
# 47591

# %%
obesity_related_df.dropna(subset=['Income'], inplace=True)
obesity_related_df
# Out:
# /tmp/ipykernel_33/1597926524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_related_df.dropna(subset=['Income'], inplace=True)
#         YearStart LocationDesc                             Topic  \
# 40098        2013     National           Obesity / Weight Status
# 40099        2013     National           Obesity / Weight Status
# 40104        2015  Puerto Rico      Physical Activity - Behavior
# 40109        2012      Wyoming      Physical Activity - Behavior
# 40118        2017   Washington  Fruits and Vegetables - Behavior
# ...           ...          ...                               ...
# 133323       2022      Wyoming      Physical Activity - Behavior
# 133327       2022      Wyoming      Physical Activity - Behavior
# ...

# %%
obesity_related_df = obesity_related_df[obesity_related_df['Income'] != 'Data not reported']
obesity_related_df
# Out:
#         YearStart LocationDesc                             Topic  \
# 40098        2013     National           Obesity / Weight Status
# 40104        2015  Puerto Rico      Physical Activity - Behavior
# 40109        2012      Wyoming      Physical Activity - Behavior
# 40118        2017   Washington  Fruits and Vegetables - Behavior
# 40122        2014  Puerto Rico           Obesity / Weight Status
# ...           ...          ...                               ...
# 133320       2022      Wyoming           Obesity / Weight Status
# 133327       2022      Wyoming      Physical Activity - Behavior
# 133339       2022      Wyoming           Obesity / Weight Status
# 133340       2022      Wyoming           Obesity / Weight Status
# 133343       2022      Wyoming           Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 40098   Percent of adults aged 18 years and older who ...        28.8
# ...

# %%
from pprint import pprint
#categorical column mapping: ordinal income column
income_mapping = {'Less than $15,000': 0,
'$15,000 - $24,999': 1,
 '$25,000 - $34,999': 2,
 '$35,000 - $49,999': 3,
 '$50,000 - $74,999': 4,
 '$75,000 or greater': 5}
pprint(income_mapping)
# Out:
# {'$15,000 - $24,999': 1,
#  '$25,000 - $34,999': 2,
#  '$35,000 - $49,999': 3,
#  '$50,000 - $74,999': 4,
#  '$75,000 or greater': 5,
#  'Less than $15,000': 0}

# %%
from scipy.stats import spearmanr
obesity_related_df['Income_Numeric'] = obesity_related_df['Income'].map(income_mapping)
obesity_related_df
# Out:
# /tmp/ipykernel_33/1510906614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_related_df['Income_Numeric'] = obesity_related_df['Income'].map(income_mapping)
#         YearStart LocationDesc                             Topic  \
# 40098        2013     National           Obesity / Weight Status
# 40104        2015  Puerto Rico      Physical Activity - Behavior
# 40109        2012      Wyoming      Physical Activity - Behavior
# 40118        2017   Washington  Fruits and Vegetables - Behavior
# 40122        2014  Puerto Rico           Obesity / Weight Status
# ...           ...          ...                               ...
# 133320       2022      Wyoming           Obesity / Weight Status
# ...

# %%
obesity_related_df.dropna(subset=['Data_Value'], inplace=True)
# Out:
# /tmp/ipykernel_33/259238927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_related_df.dropna(subset=['Data_Value'], inplace=True)

# %%
obesity_related_df.isna().sum()
# Out:
# YearStart                    0
# LocationDesc                 0
# Topic                        0
# Question                     0
# Data_Value                   0
# Data_Value_Footnote      13513
# Low_Confidence_Limit         0
# High_Confidence_Limit        0
# Sample_Size                  0
# Total                    13513
# Age(years)               13513
# Education                13513
# Gender                   13513
# Grade                    13513
# Income                       0
# Race/Ethnicity           13513
# GeoLocation                252
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# Income_Numeric               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  
plt.scatter(obesity_related_df['Income'], obesity_related_df['Data_Value'],)  
plt.title('Relationship between Income and Unhealthy Lifestyle Measure')  
plt.xlabel('Numeric Income')  
plt.ylabel('Unhealthy Lifestyle Measure (Data Value)')  
plt.grid(True)  
plt.show()


# Calculate Spearman correlation
correlation, p_value = spearmanr(obesity_related_df['Income_Numeric'], obesity_related_df['Data_Value'])

print("Spearman Correlation Coefficient:", correlation)
print("P-value:", p_value) #there exists a mild NEGATIVE correlation as expected
#null hypothesis can be rejected
# Out:
# Spearman Correlation Coefficient: -0.24680612071196742
# P-value: 1.1406356456765931e-186

# %%
obesity_df.head()
# Out:
#    YearStart          LocationDesc                         Topic  \
# 0       2019                Alaska  Physical Activity - Behavior
# 1       2019               Arizona       Obesity / Weight Status
# 2       2019  District of Columbia       Obesity / Weight Status
# 3       2019              Illinois  Physical Activity - Behavior
# 4       2019              Maryland       Obesity / Weight Status
#
#                                             Question  Data_Value  \
# 0  Percent of students in grades 9-12 who achieve...         9.6
# 1  Percent of students in grades 9-12 who have ob...        13.3
# 2  Percent of students in grades 9-12 who have ob...        17.1
# 3  Percent of students in grades 9-12 who partici...        65.9
# 4  Percent of students in grades 9-12 who have an...        16.7
#
#   Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 NaN                   5.5                   16.5
# ...

# %%
import pandas as pd
acs_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/acs_5yr_est_selected_economic_characteristics_2010-2022.csv')
acs_df.head()
# Out:
#                Label (Grouping)           Category    State   Estimate  \
# 0             EMPLOYMENT STATUS             Header  Alabama        NaN
# 1  Population 16 years and over  EMPLOYMENT STATUS  Alabama  3,714,504
# 2                In labor force  EMPLOYMENT STATUS  Alabama  2,246,848
# 3          Civilian labor force  EMPLOYMENT STATUS  Alabama  2,230,879
# 4                      Employed  EMPLOYMENT STATUS  Alabama  2,036,867
#
#   Margin of Error    Percent Percent Margin of Error  Year
# 0             NaN        NaN                     NaN  2010
# 1          ±1,588  3,714,504                     (X)  2010
# 2          ±5,576      60.5%                    ±0.1  2010
# 3          ±5,531      60.1%                    ±0.1  2010
# 4          ±5,904      54.8%                    ±0.2  2010

# %%
commodities = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/all_commodities.csv')
commodities.head()
# Out:
#     Date-Time       Value             Unit Commodity
# 0  2024-01-01  203.879130  Cents per Pound    Coffee
# 1  2023-12-01  210.310476  Cents per Pound    Coffee
# 2  2023-11-01  197.433182  Cents per Pound    Coffee
# 3  2023-10-01  183.951364  Cents per Pound    Coffee
# 4  2023-09-01  183.589048  Cents per Pound    Coffee

# %%
commodities['Commodity'].unique()
# Out:
# array(['Coffee', 'Corn', nan, 'Sugar'], dtype=object)

# %%
stock_etf_df = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/all_stock_and_etfs.csv')
stock_etf_df.head()
# Out:
#     Date-Time   Open     High      Low  Close   Volume Ticker_Symbol
# 0  2024-02-20  29.09  29.7100  29.0001  29.44  2673889           HRL
# 1  2024-02-16  29.01  29.1700  28.7650  28.99  5655091           HRL
# 2  2024-02-15  28.94  29.2210  28.8500  29.11  2380372           HRL
# 3  2024-02-14  28.76  28.8254  28.5100  28.80  2690379           HRL
# 4  2024-02-13  29.56  29.8000  28.6350  28.72  4173650           HRL

# %% [markdown]
# ### Hypothesis: There is no correlation between the value of processed food commodities such as corn, sugar, coffee and price returns of fast food stocks
# <p>The hypothesis will select time frames when the cumulative log returns of fast food stocks is greater than the cumulative log returns of the 4 etfs</p>

# %%
print(stock_etf_df['Date-Time'].min())
print(stock_etf_df['Date-Time'].max())
# Out:
# 1999-11-01
# 2024-02-23

# %%
print(commodities['Date-Time'].min())
print(commodities['Date-Time'].max())
# Out:
# 1990-01-01
# 2024-01-01

# %%
start_date = pd.to_datetime('1999-11-01')
end_date = pd.to_datetime('2024-01-01')

# %%
stock_etf_df['Date-Time'] = pd.to_datetime(stock_etf_df['Date-Time'])
stock_etf_df = stock_etf_df.sort_values(by='Date-Time')
stock_etf_df = stock_etf_df.sort_values(by='Date-Time')
stock_etf_df.head(20)
# Out:
#         Date-Time    Open    High     Low   Close   Volume Ticker_Symbol
# 163556 1999-11-01    8.38    8.75    8.38    8.75     7400           ALG
# 140278 1999-11-01   17.34   17.50   17.31   17.34    29200           VMI
# 59745  1999-11-01   26.31   26.44   25.44   25.81   722500           CAG
# 65859  1999-11-01   19.31   19.31   18.81   18.81   295000           DRI
# 15614  1999-11-01   12.15   12.21   11.72   11.90   820800           ADM
# 134164 1999-11-01   40.19   41.25   40.19   40.56   430100           YUM
# 128050 1999-11-01   19.81   19.88   19.81   19.81    13800           WEN
# 21728  1999-11-01   10.69   10.88   10.44   10.88   256800          AGCO
# 121936 1999-11-01   87.00   87.00   85.56   85.88   627000           GIS
# 27845  1999-11-01  107.50  107.60  106.50  106.50   559800           DIA
# 115822 1999-11-01   15.50   15.75   15.25   15.75   155700           TSN
# 146392 1999-11-01   41.75   42.00   41.25   41.69  3932900           MCD
# ...

# %%
stock_etf_df.reset_index(inplace=True)
stock_etf_df.head()
# Out:
#     index  Date-Time   Open   High    Low  Close  Volume Ticker_Symbol
# 0  163556 1999-11-01   8.38   8.75   8.38   8.75    7400           ALG
# 1  140278 1999-11-01  17.34  17.50  17.31  17.34   29200           VMI
# 2   59745 1999-11-01  26.31  26.44  25.44  25.81  722500           CAG
# 3   65859 1999-11-01  19.31  19.31  18.81  18.81  295000           DRI
# 4   15614 1999-11-01  12.15  12.21  11.72  11.90  820800           ADM

# %%
#calculate log returns: at 1-2 day period
stock_etf_df['log_returns'] = stock_etf_df.groupby('Ticker_Symbol')['Close'].transform(lambda x: np.log(x / x.shift(1)))
stock_etf_df.head(20)
# Out:
#      index  Date-Time    Open    High     Low   Close   Volume Ticker_Symbol  \
# 0   163556 1999-11-01    8.38    8.75    8.38    8.75     7400           ALG
# 1   140278 1999-11-01   17.34   17.50   17.31   17.34    29200           VMI
# 2    59745 1999-11-01   26.31   26.44   25.44   25.81   722500           CAG
# 3    65859 1999-11-01   19.31   19.31   18.81   18.81   295000           DRI
# 4    15614 1999-11-01   12.15   12.21   11.72   11.90   820800           ADM
# 5   134164 1999-11-01   40.19   41.25   40.19   40.56   430100           YUM
# 6   128050 1999-11-01   19.81   19.88   19.81   19.81    13800           WEN
# 7    21728 1999-11-01   10.69   10.88   10.44   10.88   256800          AGCO
# 8   121936 1999-11-01   87.00   87.00   85.56   85.88   627000           GIS
# 9    27845 1999-11-01  107.50  107.60  106.50  106.50   559800           DIA
# 10  115822 1999-11-01   15.50   15.75   15.25   15.75   155700           TSN
# ...

# %%
stock_etf_df.isna().sum()
# Out:
# index             0
# Date-Time         0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# Ticker_Symbol     0
# log_returns      29
# dtype: int64

# %%
stock_etf_df.dropna(subset=['log_returns'], inplace=True)

# %%
stock_etf_df.head(30)
# Out:
#      index  Date-Time      Open     High       Low     Close   Volume  \
# 23  140277 1999-11-02   17.3800   17.380   17.2500   17.2500    20300
# 24   15613 1999-11-02   11.9000   12.150   11.7800   12.1500   975600
# 25  103593 1999-11-02  135.9687  137.250  134.5937  134.5937  6516900
# 26  163555 1999-11-02    8.7500    8.880    8.6200    8.8800     7700
# 27   27844 1999-11-02  107.0000  107.700  105.7000  105.7000   975300
# 28   78086 1999-11-02   55.3800   57.060   55.1900   56.0600  1558700
# 29  146391 1999-11-02   42.0600   42.130   41.0600   41.2500  2250000
# 30   65858 1999-11-02   18.9400   19.380   18.9400   19.1300   259800
# 31   53630 1999-11-02    8.6000    9.000    8.2800    8.3200   157700
# 32  109707 1999-11-02   36.1300   37.630   36.1300   36.6900  1027500
# 33  134163 1999-11-02   40.5600   40.750   39.8800   39.9400   528900
# 34  115821 1999-11-02   15.7500   16.190   15.6900   15.8800   261100
# ...

# %%
len(list(stock_etf_df['Ticker_Symbol'].unique()))
# Out:
# 29

# %%
#take the cumulative log_return
ETF_Tickers = ['SPY', 'DIA', 'ONEQ','VOO']
STOCK_Tickers = list(stock_etf_df['Ticker_Symbol'].unique())
for ticker in STOCK_Tickers:
    if (ticker in ETF_Tickers):
        STOCK_Tickers.remove(ticker)
print(ETF_Tickers)
print(STOCK_Tickers)
# Out:
# ['SPY', 'DIA', 'ONEQ', 'VOO']
# ['VMI', 'ADM', 'ALG', 'CAT', 'MCD', 'DRI', 'PPC', 'DE', 'YUM', 'TSN', 'SAP', 'TSCO', 'COKE', 'SBUX', 'HSY', 'PEP', 'GIS', 'AGCO', 'WEN', 'HRL', 'CAG', 'DPZ', 'CMG', 'CNHI', 'QSR']

# %%
len(STOCK_Tickers)
# Out:
# 25

# %%
cumulative_df = stock_etf_df.copy()
cumulative_df.reset_index(inplace=True)
cumulative_df.head()
# Out:
#    level_0   index  Date-Time      Open    High       Low     Close   Volume  \
# 0       23  140277 1999-11-02   17.3800   17.38   17.2500   17.2500    20300
# 1       24   15613 1999-11-02   11.9000   12.15   11.7800   12.1500   975600
# 2       25  103593 1999-11-02  135.9687  137.25  134.5937  134.5937  6516900
# 3       26  163555 1999-11-02    8.7500    8.88    8.6200    8.8800     7700
# 4       27   27844 1999-11-02  107.0000  107.70  105.7000  105.7000   975300
#
#   Ticker_Symbol  log_returns
# 0           VMI    -0.005204
# 1           ADM     0.020791
# 2           SPY    -0.007172
# 3           ALG     0.014748
# 4           DIA    -0.007540

# %%
cumulative_df.drop(columns = ['level_0'], inplace=True)

# %%
cumulative_df['Ticker_Symbol'] = cumulative_df['Ticker_Symbol'].apply(lambda x: 'ETF' if x in ETF_Tickers else 'STOCK')
cumulative_df.head()
# Out:
#     index  Date-Time      Open    High       Low     Close   Volume  \
# 0  140277 1999-11-02   17.3800   17.38   17.2500   17.2500    20300
# 1   15613 1999-11-02   11.9000   12.15   11.7800   12.1500   975600
# 2  103593 1999-11-02  135.9687  137.25  134.5937  134.5937  6516900
# 3  163555 1999-11-02    8.7500    8.88    8.6200    8.8800     7700
# 4   27844 1999-11-02  107.0000  107.70  105.7000  105.7000   975300
#
#   Ticker_Symbol  log_returns
# 0         STOCK    -0.005204
# 1         STOCK     0.020791
# 2           ETF    -0.007172
# 3         STOCK     0.014748
# 4           ETF    -0.007540

# %%
cumulative_df = cumulative_df.groupby(['Date-Time', 'Ticker_Symbol'])['log_returns'].mean().reset_index()
cumulative_df.head()
# Out:
#    Date-Time Ticker_Symbol  log_returns
# 0 1999-11-02           ETF    -0.007356
# 1 1999-11-02         STOCK     0.000424
# 2 1999-11-03           ETF     0.005715
# 3 1999-11-03         STOCK     0.003566
# 4 1999-11-04           ETF     0.005670

# %%
cumulative_df.shape
# Out:
# (12229, 3)

# %%
commodities.head()
# Out:
#     Date-Time       Value             Unit Commodity
# 0  2024-01-01  203.879130  Cents per Pound    Coffee
# 1  2023-12-01  210.310476  Cents per Pound    Coffee
# 2  2023-11-01  197.433182  Cents per Pound    Coffee
# 3  2023-10-01  183.951364  Cents per Pound    Coffee
# 4  2023-09-01  183.589048  Cents per Pound    Coffee

# %%
import pandas as pd
commodities['Date-Time'] = pd.to_datetime(commodities['Date-Time'])

# %%
commodities = commodities.sort_values(by='Date-Time')
commodities.reset_index(inplace=True)

# %%
commodities.dropna(subset=['Commodity'], inplace=True)

# %%
commodities.drop(columns=['index'], inplace=True)

# %%
commodities['com_log_returns'] = commodities.groupby('Commodity')['Value'].transform(lambda x: np.log(x / x.shift(1)))
commodities
# Out:
#       Date-Time       Value                   Unit Commodity  com_log_returns
# 0    1990-01-01   14.200001        Cents per Pound     Sugar              NaN
# 1    1990-01-01   75.829987        Cents per Pound    Coffee              NaN
# 4    1990-02-01   84.010010        Cents per Pound    Coffee         0.102442
# 5    1990-02-01   14.650002        Cents per Pound     Sugar         0.031198
# 6    1990-03-01   93.959991        Cents per Pound    Coffee         0.111933
# ...         ...         ...                    ...       ...              ...
# 1222 2023-12-01   22.145714        Cents per Pound     Sugar        -0.209592
# 1223 2023-12-01  210.310476        Cents per Pound    Coffee         0.063185
# 1224 2024-01-01  198.757928  Dollar per Metric Ton      Corn              NaN
# 1225 2024-01-01   22.474783        Cents per Pound     Sugar         0.014750
# 1226 2024-01-01  203.879130        Cents per Pound    Coffee        -0.031058
#
# [819 rows x 5 columns]

# %%
commodities.dropna(subset=['com_log_returns'], inplace=True)

# %%
commodities
# Out:
#       Date-Time       Value             Unit Commodity  com_log_returns
# 4    1990-02-01   84.010010  Cents per Pound    Coffee         0.102442
# 5    1990-02-01   14.650002  Cents per Pound     Sugar         0.031198
# 6    1990-03-01   93.959991  Cents per Pound    Coffee         0.111933
# 7    1990-03-01   15.310001  Cents per Pound     Sugar         0.044066
# 9    1990-04-01   93.730011  Cents per Pound    Coffee        -0.002451
# ...         ...         ...              ...       ...              ...
# 1219 2023-11-01  197.433182  Cents per Pound    Coffee         0.070729
# 1222 2023-12-01   22.145714  Cents per Pound     Sugar        -0.209592
# 1223 2023-12-01  210.310476  Cents per Pound    Coffee         0.063185
# 1225 2024-01-01   22.474783  Cents per Pound     Sugar         0.014750
# 1226 2024-01-01  203.879130  Cents per Pound    Coffee        -0.031058
#
# [816 rows x 5 columns]

# %%
cumlative_commodity = commodities.copy()
cumlative_commodity['Commodity'] = 'ProcessedFood_Commodity'
cumlative_commodity
# Out:
#       Date-Time       Value             Unit                Commodity  \
# 4    1990-02-01   84.010010  Cents per Pound  ProcessedFood_Commodity
# 5    1990-02-01   14.650002  Cents per Pound  ProcessedFood_Commodity
# 6    1990-03-01   93.959991  Cents per Pound  ProcessedFood_Commodity
# 7    1990-03-01   15.310001  Cents per Pound  ProcessedFood_Commodity
# 9    1990-04-01   93.730011  Cents per Pound  ProcessedFood_Commodity
# ...         ...         ...              ...                      ...
# 1219 2023-11-01  197.433182  Cents per Pound  ProcessedFood_Commodity
# 1222 2023-12-01   22.145714  Cents per Pound  ProcessedFood_Commodity
# 1223 2023-12-01  210.310476  Cents per Pound  ProcessedFood_Commodity
# 1225 2024-01-01   22.474783  Cents per Pound  ProcessedFood_Commodity
# 1226 2024-01-01  203.879130  Cents per Pound  ProcessedFood_Commodity
#
#       com_log_returns
# 4            0.102442
# 5            0.031198
# 6            0.111933
# 7            0.044066
# ...

# %%
cumlative_commodity = cumlative_commodity.groupby(['Date-Time', 'Commodity'])['com_log_returns'].mean().reset_index()
cumlative_commodity
# Out:
#      Date-Time                Commodity  com_log_returns
# 0   1990-02-01  ProcessedFood_Commodity         0.066820
# 1   1990-03-01  ProcessedFood_Commodity         0.077999
# 2   1990-04-01  ProcessedFood_Commodity        -0.003517
# 3   1990-05-01  ProcessedFood_Commodity        -0.029973
# 4   1990-06-01  ProcessedFood_Commodity        -0.080735
# ..         ...                      ...              ...
# 403 2023-09-01  ProcessedFood_Commodity         0.039287
# 404 2023-10-01  ProcessedFood_Commodity         0.007342
# 405 2023-11-01  ProcessedFood_Commodity         0.042852
# 406 2023-12-01  ProcessedFood_Commodity        -0.073204
# 407 2024-01-01  ProcessedFood_Commodity        -0.008154
#
# [408 rows x 3 columns]

# %%
#make commodities have the same range as stock and etf dataset
#1999-11-01
#2024-02-23
cumulative_df = cumulative_df[(cumulative_df['Date-Time'] >= start_date) & (cumulative_df['Date-Time'] <= end_date)]
cumlative_commodity = cumlative_commodity[(cumlative_commodity['Date-Time'] >= start_date) & (cumlative_commodity['Date-Time'] <= end_date)]

# %%
cumulative_df
# Out:
#        Date-Time Ticker_Symbol  log_returns
# 0     1999-11-02           ETF    -0.007356
# 1     1999-11-02         STOCK     0.000424
# 2     1999-11-03           ETF     0.005715
# 3     1999-11-03         STOCK     0.003566
# 4     1999-11-04           ETF     0.005670
# ...          ...           ...          ...
# 12153 2023-12-27         STOCK     0.002802
# 12154 2023-12-28           ETF     0.000825
# 12155 2023-12-28         STOCK    -0.000125
# 12156 2023-12-29           ETF    -0.002636
# 12157 2023-12-29         STOCK     0.000917
#
# [12158 rows x 3 columns]

# %%
cumlative_commodity
# Out:
#      Date-Time                Commodity  com_log_returns
# 117 1999-11-01  ProcessedFood_Commodity         0.077453
# 118 1999-12-01  ProcessedFood_Commodity         0.003597
# 119 2000-01-01  ProcessedFood_Commodity        -0.078545
# 120 2000-02-01  ProcessedFood_Commodity        -0.061560
# 121 2000-03-01  ProcessedFood_Commodity        -0.039482
# ..         ...                      ...              ...
# 403 2023-09-01  ProcessedFood_Commodity         0.039287
# 404 2023-10-01  ProcessedFood_Commodity         0.007342
# 405 2023-11-01  ProcessedFood_Commodity         0.042852
# 406 2023-12-01  ProcessedFood_Commodity        -0.073204
# 407 2024-01-01  ProcessedFood_Commodity        -0.008154
#
# [291 rows x 3 columns]

# %%
cumulative_df = pd.merge(cumulative_df, cumlative_commodity, on='Date-Time')

# %%
cumulative_df
# Out:
#      Date-Time Ticker_Symbol  log_returns                Commodity  \
# 0   1999-12-01           ETF     0.010421  ProcessedFood_Commodity
# 1   1999-12-01         STOCK    -0.002965  ProcessedFood_Commodity
# 2   2000-02-01           ETF     0.008542  ProcessedFood_Commodity
# 3   2000-02-01         STOCK    -0.008470  ProcessedFood_Commodity
# 4   2000-03-01           ETF     0.003625  ProcessedFood_Commodity
# ..         ...           ...          ...                      ...
# 369 2023-09-01         STOCK     0.000938  ProcessedFood_Commodity
# 370 2023-11-01           ETF     0.010918  ProcessedFood_Commodity
# 371 2023-11-01         STOCK     0.004150  ProcessedFood_Commodity
# 372 2023-12-01           ETF     0.006245  ProcessedFood_Commodity
# 373 2023-12-01         STOCK     0.016583  ProcessedFood_Commodity
#
#      com_log_returns
# 0           0.003597
# 1           0.003597
# 2          -0.061560
# 3          -0.061560
# 4          -0.039482
# ..               ...
# ...

# %%
cumulative_df.isna().sum()
# Out:
# Date-Time          0
# Ticker_Symbol      0
# log_returns        0
# Commodity          0
# com_log_returns    0
# dtype: int64

# %%
pivot_log_returns = cumulative_df.pivot(index='Date-Time', columns='Ticker_Symbol', values='log_returns').reset_index()
pivot_log_returns.columns = ['Date-Time', 'etf_log_returns', 'stock_log_returns']
commodity_log_returns = cumulative_df[['Date-Time', 'Commodity', 'com_log_returns']].drop_duplicates(subset=['Date-Time'])
cumulative_df = pd.merge(pivot_log_returns, commodity_log_returns, on='Date-Time', how='left')
cumulative_df
# Out:
#      Date-Time  etf_log_returns  stock_log_returns                Commodity  \
# 0   1999-12-01         0.010421          -0.002965  ProcessedFood_Commodity
# 1   2000-02-01         0.008542          -0.008470  ProcessedFood_Commodity
# 2   2000-03-01         0.003625           0.016747  ProcessedFood_Commodity
# 3   2000-05-01         0.009057           0.008177  ProcessedFood_Commodity
# 4   2000-06-01         0.015293           0.010418  ProcessedFood_Commodity
# ..         ...              ...                ...                      ...
# 182 2023-06-01         0.008514           0.010851  ProcessedFood_Commodity
# 183 2023-08-01        -0.002026           0.001160  ProcessedFood_Commodity
# 184 2023-09-01         0.001746           0.000938  ProcessedFood_Commodity
# 185 2023-11-01         0.010918           0.004150  ProcessedFood_Commodity
# 186 2023-12-01         0.006245           0.016583  ProcessedFood_Commodity
#
#      com_log_returns
# 0           0.003597
# ...

# %%
cumulative_df = cumulative_df[cumulative_df['stock_log_returns'] >= cumulative_df['etf_log_returns']]
cumulative_df
# Out:
#      Date-Time  etf_log_returns  stock_log_returns                Commodity  \
# 2   2000-03-01         0.003625           0.016747  ProcessedFood_Commodity
# 5   2000-08-01         0.007789           0.009641  ProcessedFood_Commodity
# 6   2000-09-01         0.000513           0.008276  ProcessedFood_Commodity
# 7   2000-11-01        -0.002612           0.000248  ProcessedFood_Commodity
# 8   2000-12-01        -0.003118           0.001041  ProcessedFood_Commodity
# ..         ...              ...                ...                      ...
# 180 2023-03-01        -0.002831           0.000188  ProcessedFood_Commodity
# 181 2023-05-01        -0.001384           0.001255  ProcessedFood_Commodity
# 182 2023-06-01         0.008514           0.010851  ProcessedFood_Commodity
# 183 2023-08-01        -0.002026           0.001160  ProcessedFood_Commodity
# 186 2023-12-01         0.006245           0.016583  ProcessedFood_Commodity
#
#      com_log_returns
# 2          -0.039482
# ...

# %%
#Plot stock_log_returns vs com_log_returns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  

# Create scatter plot
plt.scatter(cumulative_df['com_log_returns'], cumulative_df['stock_log_returns'], alpha=0.5)

# Add titles and labels
plt.title('Stock Log Returns vs. Commodity Log Returns')
plt.xlabel('Commodity Log Returns')
plt.ylabel('Stock Log Returns')

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
#Plot stock_log_returns vs com_log_returns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

plt.figure(figsize=(10, 6))  # Set the figure size for better readability

# Create scatter plot
plt.scatter(cumulative_df['com_log_returns'], cumulative_df['etf_log_returns'], alpha=0.5)

# Add titles and labels
plt.title('ETF Log Returns vs. Commodity Log Returns')
plt.xlabel('Commodity Log Returns')
plt.ylabel('ETF Log Returns')

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
correlation, p_value = spearmanr(cumulative_df['com_log_returns'], cumulative_df['etf_log_returns'])

print("Spearman Correlation Coefficient:", correlation)
print("P-value:", p_value)
#there exists a mild positive correlation
#There exists a statistical signifiance
# Out:
# Spearman Correlation Coefficient: 0.13124973762646405
# P-value: 0.2369152849881596

# %%
correlation, p_value = spearmanr(cumulative_df['com_log_returns'], cumulative_df['stock_log_returns'])

print("Spearman Correlation Coefficient:", correlation)
print("P-value:", p_value)
#can not reject null hypothesis at .05 significance level, but cit can be rejected at .10
#exists a weak positive correlation
# Out:
# Spearman Correlation Coefficient: 0.09493724025019941
# P-value: 0.3932529911818996

# %% [markdown]
# <p>This might indicate that actually during times of economic upturns/downturns as businesses perform well in the economy so do the commodities this is quite expected, but the p-value indicates that this relationship might not be of stastical significance</p>

# %%
stock_etf_df
# Out:
#         Date-Time      Open    High       Low     Close    Volume  \
# 23     1999-11-02   17.3800   17.38   17.2500   17.2500     20300
# 24     1999-11-02   11.9000   12.15   11.7800   12.1500    975600
# 25     1999-11-02  135.9687  137.25  134.5937  134.5937   6516900
# 26     1999-11-02    8.7500    8.88    8.6200    8.8800      7700
# 27     1999-11-02  107.0000  107.70  105.7000  105.7000    975300
# ...           ...       ...     ...       ...       ...       ...
# 163552 2024-02-22  504.0100  508.49  503.0200  507.5000  76402535
# 163553 2024-02-23   63.4400   63.60   62.8412   63.0900    273699
# 163554 2024-02-23  509.2700  510.13  507.1000  507.8500  61321818
# 163555 2024-02-23  468.0900  468.87  466.0907  466.7800   4050621
# 163556 2024-02-23  391.7700  392.84  390.9200  391.2800   3451571
#
#        Ticker_Symbol  log_returns
# 23               VMI    -0.005204
# 24               ADM     0.020791
# 25               SPY    -0.007172
# ...

# %%
stock_etf = stock_etf_df.copy()
stock_etf['Ticker_Symbol'] = stock_etf_df['Ticker_Symbol'].apply(lambda x: 'ETF' if x in ETF_Tickers else 'STOCK')
stock_etf = stock_etf.groupby(['Date-Time', 'Ticker_Symbol'])['log_returns'].mean().reset_index()
stock_etf.head()
# Out:
#    Date-Time Ticker_Symbol  log_returns
# 0 1999-11-02           ETF    -0.007356
# 1 1999-11-02         STOCK     0.000424
# 2 1999-11-03           ETF     0.005715
# 3 1999-11-03         STOCK     0.003566
# 4 1999-11-04           ETF     0.005670

# %%
pivot_log_returns = stock_etf.pivot(index='Date-Time', columns='Ticker_Symbol', values='log_returns').reset_index()
pivot_log_returns.columns = ['Date-Time', 'etf_log_returns', 'stock_log_returns']
pivot_log_returns
# Out:
#       Date-Time  etf_log_returns  stock_log_returns
# 0    1999-11-02        -0.007356           0.000424
# 1    1999-11-03         0.005715           0.003566
# 2    1999-11-04         0.005670          -0.005486
# 3    1999-11-05         0.009101           0.012997
# 4    1999-11-08        -0.000012          -0.001527
# ...         ...              ...                ...
# 6111 2024-02-16        -0.005820          -0.005934
# 6112 2024-02-20        -0.005339           0.000105
# 6113 2024-02-21        -0.000385                NaN
# 6114 2024-02-22         0.020154                NaN
# 6115 2024-02-23         0.000520                NaN
#
# [6116 rows x 3 columns]

# %%
pivot_log_returns.dropna(subset=['stock_log_returns'], inplace=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6)) 

plt.scatter(pivot_log_returns['stock_log_returns'], pivot_log_returns['etf_log_returns'], alpha=0.5)

plt.title('ETF Log Returns vs. Stock Log Returns')
plt.xlabel('Stock Log Returns')
plt.ylabel('ETF Log Returns')
plt.grid(True)
plt.show()

# %%
#stocks follow ETFs high correlation
from sklearn.metrics import r2_score
print(r2_score(pivot_log_returns['stock_log_returns'], pivot_log_returns['etf_log_returns']))
# Out:
# 0.25203655301909567

# %% [markdown]
# # Unemployment dataset extracted for later use

# %%
employment_tickers = list(acs_df['Label (Grouping)'].unique())[0:13]

# %%
#need to prepare this for economic downturns -> based on periods of increased unemployment, GDP Contraction
employment_df = acs_df[acs_df['Label (Grouping)'].isin(employment_tickers)]
employment_df
# Out:
#                    Label (Grouping)           Category        State  \
# 0                 EMPLOYMENT STATUS             Header      Alabama
# 1      Population 16 years and over  EMPLOYMENT STATUS      Alabama
# 2                    In labor force  EMPLOYMENT STATUS      Alabama
# 3              Civilian labor force  EMPLOYMENT STATUS      Alabama
# 4                          Employed  EMPLOYMENT STATUS      Alabama
# ...                             ...                ...          ...
# 97740     Females 16 years and over  EMPLOYMENT STATUS      Wyoming
# 97875             EMPLOYMENT STATUS             Header  Puerto Rico
# 97876  Population 16 years and over  EMPLOYMENT STATUS  Puerto Rico
# 97883          Civilian labor force  EMPLOYMENT STATUS  Puerto Rico
# 97885     Females 16 years and over  EMPLOYMENT STATUS  Puerto Rico
#
#         Estimate Margin of Error    Percent Percent Margin of Error  Year
# 0            NaN             NaN        NaN                     NaN  2010
# ...

# %% [markdown]
# ### Exploring the relationship between healthcare expenditure and obesity rate

# %%
health_insurance_tickers = ['HEALTH INSURANCE COVERAGE',
 '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population',
 '\xa0\xa0\xa0\xa0With health insurance coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
 '\xa0\xa0\xa0\xa0No health insurance coverage',
 'Civilian noninstitutionalized population under 18 years',
 'Civilian noninstitutionalized population 18 to 64 years',
 '\xa0\xa0\xa0\xa0In labor force:',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed:',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed:',
 '\xa0\xa0\xa0\xa0Not in labor force:',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
 '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage']

# %%
len(health_insurance_tickers)
# Out:
# 20

# %%
#need to prepare this for economic downturns -> based on periods of increased unemployment, GDP Contraction
health_insurance_df = acs_df[acs_df['Label (Grouping)'].isin(health_insurance_tickers)]
health_insurance_df.tail(22)
# Out:
#                                     Label (Grouping)  \
# 97830                      HEALTH INSURANCE COVERAGE
# 97831       Civilian noninstitutionalized population
# 97832                 With health insurance coverage
# 97833                  With private health insurance
# 97834                           With public coverage
# 97835                   No health insurance coverage
# 97837                   No health insurance coverage
# 97851                 With health insurance coverage
# 97852                  With private health insurance
# 97853                           With public coverage
# 97854                   No health insurance coverage
# 97975                      HEALTH INSURANCE COVERAGE
# 97976       Civilian noninstitutionalized population
# 97977                 With health insurance coverage
# 97978                  With private health insurance
# 97979                           With public coverage
# 97980                   No health insurance coverage
# ...

# %%
health_insurance_df['Year'].unique()
# Out:
# array([2010, 2011, 2013, 2012, 2016, 2017, 2015, 2014, 2019, 2018, 2022,
#        2020, 2021])

# %%
health_insurance_df.isna().sum()
# Out:
# Label (Grouping)             0
# Category                     0
# State                        0
# Estimate                   676
# Margin of Error            676
# Percent                    676
# Percent Margin of Error    676
# Year                         0
# dtype: int64

# %%
health_insurance_df.dropna(subset=['Percent'], inplace=True)
# Out:
# /tmp/ipykernel_33/1457480635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_insurance_df.dropna(subset=['Percent'], inplace=True)

# %%
health_insurance_df['Year'].unique()
# Out:
# array([2010, 2011, 2013, 2012, 2016, 2017, 2015, 2014, 2019, 2018, 2022,
#        2020, 2021])

# %%
health_insurance_df = health_insurance_df[health_insurance_df['Percent'] != '(X)']

# %%
health_insurance_df['Year'].unique()
# Out:
# array([2013, 2012, 2016, 2017, 2015, 2014, 2019, 2018, 2022, 2020, 2021])

# %%
health_insurance_df['Label (Grouping)'] = health_insurance_df['Label (Grouping)'].str.strip()

indices_to_keep = []

for i in health_insurance_df.index[:-1]:  
    if health_insurance_df.loc[i, 'Label (Grouping)'] == 'Civilian noninstitutionalized population' and \
       health_insurance_df.loc[i + 1, 'Label (Grouping)'] == 'With health insurance coverage':
        indices_to_keep.append(i)  
        indices_to_keep.append(i+1)  


health_insurance_df = health_insurance_df.loc[indices_to_keep]

# %%
health_insurance_df
# Out:
#                                Label (Grouping)                   Category  \
# 15181  Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
# 15182            With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15326  Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
# 15327            With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15471  Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
# ...                                         ...                        ...
# 97687            With health insurance coverage  HEALTH INSURANCE COVERAGE
# 97831  Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
# 97832            With health insurance coverage  HEALTH INSURANCE COVERAGE
# 97976  Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
# 97977            With health insurance coverage  HEALTH INSURANCE COVERAGE
#
#              State   Estimate Margin of Error    Percent  \
# ...

# %%
health_insurance_df['Label (Grouping)'].unique()
# Out:
# array(['Civilian noninstitutionalized population',
#        'With health insurance coverage'], dtype=object)

# %%
health_insurance_df = health_insurance_df[health_insurance_df['Label (Grouping)'] == 'With health insurance coverage']

# %%
health_insurance_df['Year'].unique()
# Out:
# array([2013, 2012, 2016, 2017, 2015, 2014, 2019, 2018, 2022, 2020, 2021])

# %%
health_insurance_df['Percent'] = health_insurance_df['Percent'].apply(lambda x: float(x.rstrip('%')) / 100)
health_insurance_df
# Out:
# /tmp/ipykernel_33/140549658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_insurance_df['Percent'] = health_insurance_df['Percent'].apply(lambda x: float(x.rstrip('%')) / 100)
#                      Label (Grouping)                   Category  \
# 15182  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15327  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15472  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15617  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 15762  With health insurance coverage  HEALTH INSURANCE COVERAGE
# ...                               ...                        ...
# 97397  With health insurance coverage  HEALTH INSURANCE COVERAGE
# ...

# %%
health_insurance_df = health_insurance_df.sort_values(by='Year')

# %%
#ADF test for stationarity on dataset
from statsmodels.tsa.stattools import adfuller
result = adfuller(health_insurance_df['Percent'])

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %f' % (key, value))
#nonstationary dataset
# Out:
# ADF Statistic: -1.553098
# p-value: 0.507100
# Critical Values:
# 	1%: -3.442145
# 	5%: -2.866743
# 	10%: -2.569541

# %%
health_insurance_df
# Out:
#                      Label (Grouping)                   Category  \
# 26347  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 26057  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25912  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25767  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25622  With health insurance coverage  HEALTH INSURANCE COVERAGE
# ...                               ...                        ...
# 78547  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78692  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78837  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82897  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82752  With health insurance coverage  HEALTH INSURANCE COVERAGE
#
#                State   Estimate Margin of Error  Percent  \
# 26347       Missouri  5,100,832          ±9,767    0.869
# 26057      Minnesota  4,799,301          ±7,605    0.913
# ...

# %%
health_insurance_df.columns
# Out:
# Index(['Label (Grouping)', 'Category', 'State', 'Estimate', 'Margin of Error',
#        'Percent', 'Percent Margin of Error', 'Year'],
#       dtype='object')

# %%
#generate a plot of percentage against year
#this is to check if there isn't already a trend present
import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(10, 6))
plt.scatter(health_insurance_df['Year'], health_insurance_df['Percent'], marker='o', linestyle='-')

plt.title('Health Insurance Coverage Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage with Health Insurance')
plt.grid(True)

if isinstance(health_insurance_df['Year'].dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
    plt.gcf().autofmt_xdate() 

plt.show()
# no solid trend exists hence findings won't be biased

# %%
health_insurance_df['Percent_Diff'] = health_insurance_df.groupby('State')['Percent'].diff()
#applying seasonal differencing for future use with stationary casuality tests

# %%
health_insurance_df
# Out:
#                      Label (Grouping)                   Category  \
# 26347  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 26057  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25912  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25767  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 25622  With health insurance coverage  HEALTH INSURANCE COVERAGE
# ...                               ...                        ...
# 78547  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78692  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78837  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82897  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82752  With health insurance coverage  HEALTH INSURANCE COVERAGE
#
#                State   Estimate Margin of Error  Percent  \
# 26347       Missouri  5,100,832          ±9,767    0.869
# 26057      Minnesota  4,799,301          ±7,605    0.913
# ...

# %%
h_p_diff_df = health_insurance_df.dropna(subset=['Percent_Diff'])

# %%
h_p_diff_df
# Out:
#                      Label (Grouping)                   Category  \
# 15182  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 22432  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 18517  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 18372  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 18227  With health insurance coverage  HEALTH INSURANCE COVERAGE
# ...                               ...                        ...
# 78547  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78692  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 78837  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82897  With health insurance coverage  HEALTH INSURANCE COVERAGE
# 82752  With health insurance coverage  HEALTH INSURANCE COVERAGE
#
#                State   Estimate Margin of Error  Percent  \
# 15182        Alabama  4,061,521          ±9,027    0.861
# 22432        Wyoming    476,786          ±2,738    0.851
# ...

# %%
obesity_df
# Out:
#         YearStart          LocationDesc                         Topic  \
# 0            2019                Alaska  Physical Activity - Behavior
# 1            2019               Arizona       Obesity / Weight Status
# 2            2019  District of Columbia       Obesity / Weight Status
# 3            2019              Illinois  Physical Activity - Behavior
# 4            2019              Maryland       Obesity / Weight Status
# ...           ...                   ...                           ...
# 133340       2022               Wyoming       Obesity / Weight Status
# 133341       2022               Wyoming  Physical Activity - Behavior
# 133342       2022               Wyoming       Obesity / Weight Status
# 133343       2022               Wyoming       Obesity / Weight Status
# 133344       2022               Wyoming       Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# ...

# %%
obesity_time_series = obesity_related_df[['YearStart', 'Question', 'LocationDesc', 'Data_Value']]
obesity_time_series = obesity_time_series.rename(columns={'LocationDesc': 'State', 'YearStart': 'Year'})
obesity_time_series
# Out:
#         Year                                           Question        State  \
# 40098   2013  Percent of adults aged 18 years and older who ...     National
# 40104   2015  Percent of adults who engage in no leisure-tim...  Puerto Rico
# 40109   2012  Percent of adults who engage in no leisure-tim...      Wyoming
# 40118   2017  Percent of adults who report consuming fruit l...   Washington
# 40122   2014  Percent of adults aged 18 years and older who ...  Puerto Rico
# ...      ...                                                ...          ...
# 133320  2022  Percent of adults aged 18 years and older who ...      Wyoming
# 133327  2022  Percent of adults who engage in no leisure-tim...      Wyoming
# 133339  2022  Percent of adults aged 18 years and older who ...      Wyoming
# 133340  2022  Percent of adults aged 18 years and older who ...      Wyoming
# 133343  2022  Percent of adults aged 18 years and older who ...      Wyoming
#
#         Data_Value
# 40098         28.8
# ...

# %%
obesity_time_series = pd.merge(h_p_diff_df, obesity_time_series, on=['Year', 'State'], how='inner')
obesity_time_series
# Out:
#                      Label (Grouping)                   Category    State  \
# 0      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 1      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 2      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 3      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 4      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# ...                               ...                        ...      ...
# 11156  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11157  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11158  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11159  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11160  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
#
#         Estimate Margin of Error  Percent Percent Margin of Error  Year  \
# ...

# %%
#Plotting Year against Data_Value to understand if 
#there already exists obesity related trend to avoid bias
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for state in obesity_time_series['State'].unique():
    plt.scatter(obesity_time_series[obesity_time_series['State'] == state]['Year'], 
             obesity_time_series[obesity_time_series['State'] == state]['Data_Value'], label=state)

plt.title('Yearly Percentage Change by State')
plt.xlabel('Year')
plt.ylabel('Obesity percentages')
plt.legend()  
plt.show()
#pretty random scatter plot indicates no trend exists

# %%
obesity_time_series['Data_Value'] = obesity_time_series['Data_Value'].apply(lambda x: x / 100)
obesity_time_series
# Out:
#                      Label (Grouping)                   Category    State  \
# 0      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 1      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 2      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 3      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# 4      With health insurance coverage  HEALTH INSURANCE COVERAGE  Alabama
# ...                               ...                        ...      ...
# 11156  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11157  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11158  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11159  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
# 11160  With health insurance coverage  HEALTH INSURANCE COVERAGE  Wyoming
#
#         Estimate Margin of Error  Percent Percent Margin of Error  Year  \
# ...

# %%
#ADF stationarity test -> for future use
from statsmodels.tsa.stattools import adfuller
result = adfuller(obesity_time_series['Data_Value'])

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %f' % (key, value))
# Out:
# ADF Statistic: -13.868209
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430938
# 	5%: -2.861800
# 	10%: -2.566908

# %%
# !pip3 install seaborn

# %%
#make a facetgrid scatter plot that shows the relationship statewise

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(obesity_time_series, col ='State', col_wrap = 4, height = 3, sharex=False, sharey =False)
g.map(plt.scatter, 'Percent', 'Data_Value')

g.fig.subplots_adjust(top=0.9)  # adjust the top height to accommodate title
g.fig.suptitle('Obesity Rate vs. Health Insurance Coverage Percentage by State', fontsize=16)
g.set_axis_labels('Health Insurance Coverage Percentage', 'Obesity Rate (%)')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

r2_scores = {}

# Iterate through each state to fit a model and calculate the R^2 score
for state in obesity_time_series['State'].unique():
    state_data = obesity_time_series[obesity_time_series['State'] == state]
    
    if len(state_data) > 1:
        # Reshape for sklearn
        X = state_data['Percent'].values.reshape(-1, 1)
        y = state_data['Data_Value'].values
        
        # Fit linear model
        model = LinearRegression().fit(X, y)
        
        # Calculate R^2 score and store it
        r2_scores[state] = model.score(X, y)  # model.score() returns the R^2 score directly
        
print(r2_scores)

cumulative_r2_score = np.mean(list(r2_scores.values()))
print("Cumulative R^2 Score:", cumulative_r2_score)
# Out:
# {'Alabama': 0.005320397011947753, 'Wyoming': 0.0005005364955303904, 'Minnesota': 0.007011572133398425, 'Michigan': 0.0025582816346837456, 'Massachusetts': 0.002231783938449472, 'Maryland': 0.0022644168330324677, 'Maine': 0.003544213611382574, 'Louisiana': 0.006853323862272553, 'Kentucky': 0.004881362552969892, 'Kansas': 0.005746734166622747, 'Iowa': 0.006302874903059363, 'Indiana': 0.004070092611158205, 'Illinois': 0.010926678448575644, 'Idaho': 0.0035035596058419216, 'Hawaii': 0.015872688314143568, 'Georgia': 0.002792141357802591, 'Florida': 0.0031081567195776483, 'District of Columbia': 0.005855105079067058, 'Delaware': 0.00038185016250058545, 'Connecticut': 0.009497312830541782, 'Colorado': 0.01398868681151988, 'California': 0.017151098601645987, 'Arkansas': 0.0002746690069779234, 'Arizona': 0.01093586345274744, 'Puerto Rico': 0.009406937831000106, 'Mississippi': 0.0006172029488109576, 'Missouri': 0.0073260492170386105, 'Alaska': 0.006866684100614084, 'Texas': 0.000581420259754050
# ...

# %%
import pandas as pd
from scipy.stats import spearmanr

# Initialize a dictionary to store the Spearman correlation coefficients
spearman_correlations = {}

# Iterate through each state to calculate the Spearman correlation coefficient
for state in obesity_time_series['State'].unique():
    state_data = obesity_time_series[obesity_time_series['State'] == state]
    correlation, _ = spearmanr(state_data['Percent'], state_data['Data_Value'])
    spearman_correlations[state] = correlation

# Convert the dictionary to a DataFrame for easier manipulation
spearman_df = pd.DataFrame(list(spearman_correlations.items()), columns=['State', 'Spearman_Correlation'])

# %%
spearman_df
# Out:
#                    State  Spearman_Correlation
# 0                Alabama              0.085153
# 1                Wyoming              0.017324
# 2              Minnesota              0.099877
# 3               Michigan              0.071827
# 4          Massachusetts              0.056766
# 5               Maryland              0.073219
# 6                  Maine              0.107986
# 7              Louisiana              0.085283
# 8               Kentucky              0.094997
# 9                 Kansas              0.110747
# 10                  Iowa              0.118645
# 11               Indiana              0.089081
# 12              Illinois              0.143000
# 13                 Idaho              0.097276
# 14                Hawaii              0.111355
# 15               Georgia              0.046753
# 16               Florida              0.061467
# 17  District of Columbia              0.065931
# 18              Delaware              0.028386
# ...

# %%
mean_spearman_correlation = spearman_df['Spearman_Correlation'].mean()
print("Mean Spearman Correlation Coefficient across all states:", mean_spearman_correlation)o
# Out:
#   Cell In[180], line 2
#     print("Mean Spearman Correlation Coefficient across all states:", mean_spearman_correlation)o
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
#Plotting Obesity Rates against Health Insurance Coverage Percentage to understand if 
#there already exists obesity related trend to avoid bias
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for state in obesity_time_series['State'].unique():
    plt.scatter(obesity_time_series[obesity_time_series['State'] == state]['Percent'], 
             obesity_time_series[obesity_time_series['State'] == state]['Data_Value'], label=state)
plt.title('Obesity Rate vs. Health Insurance Coverage Percentage by State')
plt.xlabel('Health Insurance Coverage Percentage')
plt.ylabel('Obesity Rate (%)')
plt.legend(loc='best', fontsize='small', ncol=2)  # Adjusting legend to make it more manageable
plt.show()

# %% [markdown]
# ### Assessing Impact of State-obesity Rates on Labor Level on Market Outcomes

# %%
obesity_related_df
# Out:
#         YearStart LocationDesc                             Topic  \
# 40098        2013     National           Obesity / Weight Status
# 40104        2015  Puerto Rico      Physical Activity - Behavior
# 40109        2012      Wyoming      Physical Activity - Behavior
# 40118        2017   Washington  Fruits and Vegetables - Behavior
# 40122        2014  Puerto Rico           Obesity / Weight Status
# ...           ...          ...                               ...
# 133320       2022      Wyoming           Obesity / Weight Status
# 133327       2022      Wyoming      Physical Activity - Behavior
# 133339       2022      Wyoming           Obesity / Weight Status
# 133340       2022      Wyoming           Obesity / Weight Status
# 133343       2022      Wyoming           Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 40098   Percent of adults aged 18 years and older who ...        28.8
# ...

# %%
employment_df
# Out:
#                    Label (Grouping)           Category        State  \
# 0                 EMPLOYMENT STATUS             Header      Alabama
# 1      Population 16 years and over  EMPLOYMENT STATUS      Alabama
# 2                    In labor force  EMPLOYMENT STATUS      Alabama
# 3              Civilian labor force  EMPLOYMENT STATUS      Alabama
# 4                          Employed  EMPLOYMENT STATUS      Alabama
# ...                             ...                ...          ...
# 97740     Females 16 years and over  EMPLOYMENT STATUS      Wyoming
# 97875             EMPLOYMENT STATUS             Header  Puerto Rico
# 97876  Population 16 years and over  EMPLOYMENT STATUS  Puerto Rico
# 97883          Civilian labor force  EMPLOYMENT STATUS  Puerto Rico
# 97885     Females 16 years and over  EMPLOYMENT STATUS  Puerto Rico
#
#         Estimate Margin of Error    Percent Percent Margin of Error  Year
# 0            NaN             NaN        NaN                     NaN  2010
# ...

# %% [markdown]
# ### Exploring the relationship between poverty and obesity

# %%
poverty_tickers = ['PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL',
 '\xa0\xa0\xa0\xa0All families',
 'With related children under 18 years',
 'With related children under 5 years only',
 '\xa0\xa0\xa0\xa0Married couple families',
 '\xa0\xa0\xa0\xa0Families with female householder, no husband present',
 '\xa0\xa0\xa0\xa0All people',
 'Under 18 years',
 'Related children under 18 years',
 'Related children under 5 years',
 'Related children 5 to 17 years',
 '18 years and over',
 '18 to 64 years',
 '65 years and over',
 '\xa0\xa0\xa0\xa0People in families',
 'Unrelated individuals 15 years and over',]

# %%
poverty_df = acs_df[acs_df['Label (Grouping)'].isin(poverty_tickers)]
poverty_df.tail(10)
# Out:
#                                         Label (Grouping)  \
# 97872                                  65 years and over
# 97874            Unrelated individuals 15 years and over
# 98000  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 98001                                       All families
# 98010                                         All people
# 98011                                     Under 18 years
# 98015                                  18 years and over
# 98016                                     18 to 64 years
# 98017                                  65 years and over
# 98019            Unrelated individuals 15 years and over
#
#                                                 Category        State  \
# 97872  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...      Wyoming
# 97874  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...      Wyoming
# 98000                                             Header  Puerto Rico
# ...

# %%
poverty_df['Label (Grouping)'] = poverty_df['Label (Grouping)'].apply(lambda x: x.replace('\xa0', '').strip())
cleaned_labels = poverty_df['Label (Grouping)'].unique()
print(cleaned_labels)
# Out:
# ['PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'
#  'All families' 'With related children under 18 years'
#  'With related children under 5 years only' 'Married couple families'
#  'Families with female householder, no husband present' 'All people'
#  'Under 18 years' 'Related children under 18 years'
#  'Related children under 5 years' 'Related children 5 to 17 years'
#  '18 years and over' '18 to 64 years' '65 years and over'
#  'People in families' 'Unrelated individuals 15 years and over']
# /tmp/ipykernel_33/1230441992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty_df['Label (Grouping)'] = poverty_df['Label (Grouping)'].apply(lambda x: x.replace('\xa0', '').strip())

# %%
poverty_df.dropna(subset=['Percent'], inplace=True)
poverty_df = poverty_df[poverty_df['Percent'] != '(X)']
poverty_df
# Out:
# /tmp/ipykernel_33/44948379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty_df.dropna(subset=['Percent'], inplace=True)
#                                Label (Grouping)  \
# 126                                All families
# 127        With related children under 18 years
# 128    With related children under 5 years only
# 129                     Married couple families
# 130        With related children under 18 years
# ...                                         ...
# 98011                            Under 18 years
# 98015                         18 years and over
# 98016                            18 to 64 years
# 98017                         65 years and over
# 98019   Unrelated individuals 15 years and over
#
# ...

# %%
broader_poverty_df = poverty_df[poverty_df['Label (Grouping)'] == 'All families']
broader_poverty_df
# Out:
#       Label (Grouping)                                           Category  \
# 126       All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 271       All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 416       All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 561       All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 706       All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# ...                ...                                                ...
# 97421     All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 97566     All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 97711     All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 97856     All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# 98001     All families  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
#
#                State Estimate Margin of Error Percent Percent Margin of Error  \
# ...

# %%
obesity_poverty_df = obesity_df.rename(columns={'YearStart': 'Year', 'LocationDesc': 'State'})
obesity_poverty_df
# Out:
#         Year                 State                         Topic  \
# 0       2019                Alaska  Physical Activity - Behavior
# 1       2019               Arizona       Obesity / Weight Status
# 2       2019  District of Columbia       Obesity / Weight Status
# 3       2019              Illinois  Physical Activity - Behavior
# 4       2019              Maryland       Obesity / Weight Status
# ...      ...                   ...                           ...
# 133340  2022               Wyoming       Obesity / Weight Status
# 133341  2022               Wyoming  Physical Activity - Behavior
# 133342  2022               Wyoming       Obesity / Weight Status
# 133343  2022               Wyoming       Obesity / Weight Status
# 133344  2022               Wyoming       Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 0       Percent of students in grades 9-12 who achieve...         9.6
# ...

# %%
obesity_tickers = ['Q047', 'Q036', 'Q037', 'Q018', 'Q019']
obesity_poverty_df = obesity_poverty_df[obesity_poverty_df['QuestionID'].isin(obesity_tickers)]
obesity_poverty_df
# Out:
#         Year     State                         Topic  \
# 40096   2020  National  Physical Activity - Behavior
# 40097   2014      Guam       Obesity / Weight Status
# 40098   2013  National       Obesity / Weight Status
# 40099   2013  National       Obesity / Weight Status
# 40102   2012   Wyoming       Obesity / Weight Status
# ...      ...       ...                           ...
# 133340  2022   Wyoming       Obesity / Weight Status
# 133341  2022   Wyoming  Physical Activity - Behavior
# 133342  2022   Wyoming       Obesity / Weight Status
# 133343  2022   Wyoming       Obesity / Weight Status
# 133344  2022   Wyoming       Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 40096   Percent of adults who engage in no leisure-tim...        30.6
# 40097   Percent of adults aged 18 years and older who ...        29.3
# 40098   Percent of adults aged 18 years and older who ...        28.8
# ...

# %%
obesity_poverty_df.isna().sum()
# Out:
# Year                         0
# State                        0
# Topic                        0
# Question                     0
# Data_Value                6239
# Data_Value_Footnote      57214
# Low_Confidence_Limit      6239
# High_Confidence_Limit     6239
# Sample_Size               6239
# Total                    61187
# Age(years)               49857
# Education                54389
# Gender                   58921
# Grade                    63453
# Income                   47591
# Race/Ethnicity           45325
# GeoLocation               1176
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# dtype: int64

# %%
obesity_poverty_df.dropna(subset=['Race/Ethnicity'], inplace=True)
# Out:
# /tmp/ipykernel_33/2786656648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_poverty_df.dropna(subset=['Race/Ethnicity'], inplace=True)

# %%
obesity_poverty_df = pd.merge(obesity_poverty_df, broader_poverty_df, on=['Year', 'State'], how='inner')
obesity_poverty_df
# Out:
#        Year         State                         Topic  \
# 0      2012       Wyoming       Obesity / Weight Status
# 1      2015  Rhode Island       Obesity / Weight Status
# 2      2020      Delaware  Physical Activity - Behavior
# 3      2011  Rhode Island       Obesity / Weight Status
# 4      2016    California  Physical Activity - Behavior
# ...     ...           ...                           ...
# 17371  2022       Wyoming       Obesity / Weight Status
# 17372  2022       Wyoming       Obesity / Weight Status
# 17373  2022       Wyoming       Obesity / Weight Status
# 17374  2022       Wyoming       Obesity / Weight Status
# 17375  2022       Wyoming       Obesity / Weight Status
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        48.5
# 1      Percent of adults aged 18 years and older who ...        40.2
# 2      Percent of adults who engage in no leisure-tim...        15.3
# ...

# %%
obesity_poverty_df['Percent'] = obesity_poverty_df['Percent'].apply(lambda x: float(x.rstrip('%')) / 100)
obesity_poverty_df
# Out:
#        Year         State                         Topic  \
# 0      2012       Wyoming       Obesity / Weight Status
# 1      2015  Rhode Island       Obesity / Weight Status
# 2      2020      Delaware  Physical Activity - Behavior
# 3      2011  Rhode Island       Obesity / Weight Status
# 4      2016    California  Physical Activity - Behavior
# ...     ...           ...                           ...
# 17371  2022       Wyoming       Obesity / Weight Status
# 17372  2022       Wyoming       Obesity / Weight Status
# 17373  2022       Wyoming       Obesity / Weight Status
# 17374  2022       Wyoming       Obesity / Weight Status
# 17375  2022       Wyoming       Obesity / Weight Status
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        48.5
# 1      Percent of adults aged 18 years and older who ...        40.2
# 2      Percent of adults who engage in no leisure-tim...        15.3
# ...

# %%
obesity_poverty_df.dropna(subset=['Data_Value'], inplace=True)

# %%
#first make a plot of the interested quantities -> unhealthy lifestyle percentages (obesity) vs poverty stricken families percentages
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(10, 6))
sns.scatterplot(data=obesity_poverty_df, x='Percent', y='Data_Value', hue='State', style = 'Year', s= 100)

plt.title('Unhealthy Lifestyle vs. Poverty-Stricken Percentages', fontsize=14)
plt.xlabel('Poverty-Stricken Percentage', fontsize=12)
plt.ylabel('Unhealthy Lifestyle Percentage (e.g., Obesity)', fontsize=12)

plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_33/532730304.py:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
#specific regions have higher poverty such as utah
#obesity percentages are more normally distributed
#poverty percentages are skewed towards left
#non-linear relationship

# %%
correlation, p_value = spearmanr(obesity_poverty_df['Percent'], obesity_poverty_df['Data_Value'])

print("Spearman Correlation Coefficient:", correlation)
print("p_value:", p_value)
#statistically significant relationship ->  positive relationship
# Out:
# Spearman Correlation Coefficient: 0.05418486754947376
# p_value: 5.017374514718571e-09

# %%
#Understanding which racial groups are most prone 
obesity_poverty_df = obesity_poverty_df.drop(columns = ['Estimate', 'Category','Label (Grouping)', 'Margin of Error', 'Total','Income','Data_Value_Footnote'])

# %%
obesity_poverty_df['Race/Ethnicity'].unique()
# Out:
# array(['American Indian/Alaska Native', 'Hispanic', 'Asian', 'Other',
#        '2 or more races', 'Non-Hispanic White', 'Non-Hispanic Black',
#        'Hawaiian/Pacific Islander'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(obesity_poverty_df, x='Percent', hue='Race/Ethnicity', kind='kde', fill=True)

plt.title('Distribution of Percentage Values')
plt.xlabel('Percent')
plt.ylabel('Density')

# Show the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
percentiles = obesity_poverty_df.groupby('Race/Ethnicity')['Percent'].quantile([0.25, 0.5, 0.75]).unstack().transpose()
percentiles
# Out:
# Race/Ethnicity  2 or more races  American Indian/Alaska Native  Asian  \
# 0.25                      0.075                          0.075  0.074
# 0.50                      0.091                          0.093  0.089
# 0.75                      0.115                          0.116  0.109
#
# Race/Ethnicity  Hawaiian/Pacific Islander  Hispanic  Non-Hispanic Black  \
# 0.25                                0.065     0.075              0.0770
# 0.50                                0.074     0.091              0.0970
# 0.75                                0.089     0.116              0.1205
#
# Race/Ethnicity  Non-Hispanic White  Other
# 0.25                         0.075  0.071
# 0.50                         0.091  0.087
# 0.75                         0.116  0.108

# %%
obesity_poverty_df['Percent'] = obesity_poverty_df['Percent'] * 100

# %%
obesity_poverty_df
# Out:
#        Year         State                         Topic  \
# 0      2012       Wyoming       Obesity / Weight Status
# 1      2015  Rhode Island       Obesity / Weight Status
# 2      2020      Delaware  Physical Activity - Behavior
# 3      2011  Rhode Island       Obesity / Weight Status
# 4      2016    California  Physical Activity - Behavior
# ...     ...           ...                           ...
# 17364  2022       Wyoming  Physical Activity - Behavior
# 17365  2022       Wyoming       Obesity / Weight Status
# 17370  2022       Wyoming       Obesity / Weight Status
# 17372  2022       Wyoming       Obesity / Weight Status
# 17374  2022       Wyoming       Obesity / Weight Status
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        48.5
# 1      Percent of adults aged 18 years and older who ...        40.2
# 2      Percent of adults who engage in no leisure-tim...        15.3
# ...

# %%
#Calculate the mean unhealthy lifestyle percentage value
#for each race within each state
grouped_obesity_rates = obesity_poverty_df.groupby(['State', 'Race/Ethnicity']).agg({
    'Data_Value': ['mean', 'std', 'min', 'max', 'count'], 
    'Percent': ['mean', 'std', 'min', 'max', 'count'] 
})
grouped_data
# Out:
#                                       Data_Value                               \
#                                             mean        std   min   max count
# State   Race/Ethnicity
# Alabama 2 or more races                31.677500   9.041882  14.2  51.4    40
#         American Indian/Alaska Native  32.927027   8.364165  15.7  56.4    37
#         Hispanic                       31.471429   7.179758  16.2  45.0    42
#         Non-Hispanic Black             36.135714   6.963102  26.5  50.2    42
#         Non-Hispanic White             32.507143   6.365930  16.4  49.6    42
# ...                                          ...        ...   ...   ...   ...
# Wyoming 2 or more races                30.150000  10.900577  13.4  53.9    32
#         American Indian/Alaska Native  33.625806   9.082583  13.5  48.5    31
#         Hispanic                       32.028571   7.343698  19.8  49.6    42
#         Non-Hispanic White             29.207143   7.159554  14.2  42.5    42
# ...

# %%
grouped_obesity_rates
# Out:
#                                       Data_Value                               \
#                                             mean        std   min   max count
# State   Race/Ethnicity
# Alabama 2 or more races                31.677500   9.041882  14.2  51.4    40
#         American Indian/Alaska Native  32.927027   8.364165  15.7  56.4    37
#         Hispanic                       31.471429   7.179758  16.2  45.0    42
#         Non-Hispanic Black             36.135714   6.963102  26.5  50.2    42
#         Non-Hispanic White             32.507143   6.365930  16.4  49.6    42
# ...                                          ...        ...   ...   ...   ...
# Wyoming 2 or more races                30.150000  10.900577  13.4  53.9    32
#         American Indian/Alaska Native  33.625806   9.082583  13.5  48.5    31
#         Hispanic                       32.028571   7.343698  19.8  49.6    42
#         Non-Hispanic White             29.207143   7.159554  14.2  42.5    42
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

order = sorted(obesity_poverty_df['Race/Ethnicity'].unique())

g = sns.FacetGrid(obesity_poverty_df, col='State', col_wrap=4, height=3, sharey=True)
g.map(sns.boxplot, 'Race/Ethnicity', 'Data_Value', order=order)

g.set_xticklabels(rotation=90)
g.set_axis_labels('Race/Ethnicity', 'Obesity Rates (%)')

plt.subplots_adjust(top=0.92)
g.fig.suptitle('Distribution of Poverty Stricken Families Obesity Rates by Race in Each State', fontsize=16)
plt.legend()
plt.show()
#graph can be analysed to understand which racial
#groups are most prone to obesity and poverty

# %%
print(order) #order of plotting
# Out:
# ['2 or more races', 'American Indian/Alaska Native', 'Asian', 'Hawaiian/Pacific Islander', 'Hispanic', 'Non-Hispanic Black', 'Non-Hispanic White', 'Other']

# %%
obesity_related_df
# Out:
#         YearStart LocationDesc                             Topic  \
# 40098        2013     National           Obesity / Weight Status
# 40104        2015  Puerto Rico      Physical Activity - Behavior
# 40109        2012      Wyoming      Physical Activity - Behavior
# 40118        2017   Washington  Fruits and Vegetables - Behavior
# 40122        2014  Puerto Rico           Obesity / Weight Status
# ...           ...          ...                               ...
# 133320       2022      Wyoming           Obesity / Weight Status
# 133327       2022      Wyoming      Physical Activity - Behavior
# 133339       2022      Wyoming           Obesity / Weight Status
# 133340       2022      Wyoming           Obesity / Weight Status
# 133343       2022      Wyoming           Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 40098   Percent of adults aged 18 years and older who ...        28.8
# ...

# %% [markdown]
# ### Assessing the impact of state-level obesity rates on labour market outcomes: An Analysis Using GMM to Account for Endogeneity

# %%
obesity_tickers = ['Q038', 'Q039', 'Q036','Q037']
obesity_df = obesity_df[obesity_df['QuestionID'].isin(obesity_tickers)]
obesity_df
# Out:
#         YearStart          LocationDesc                    Topic  \
# 1            2019               Arizona  Obesity / Weight Status
# 2            2019  District of Columbia  Obesity / Weight Status
# 4            2019              Maryland  Obesity / Weight Status
# 5            2011          Rhode Island  Obesity / Weight Status
# 6            2019               Montana  Obesity / Weight Status
# ...           ...                   ...                      ...
# 133339       2022               Wyoming  Obesity / Weight Status
# 133340       2022               Wyoming  Obesity / Weight Status
# 133342       2022               Wyoming  Obesity / Weight Status
# 133343       2022               Wyoming  Obesity / Weight Status
# 133344       2022               Wyoming  Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 1       Percent of students in grades 9-12 who have ob...        13.3
# ...

# %% [markdown]
# ## Wrangling ACS_DF

# %%
#independent variables: employment data, average income 
acs_df
# Out:
#                               Label (Grouping)  \
# 0                            EMPLOYMENT STATUS
# 1                 Population 16 years and over
# 2                               In labor force
# 3                         Civilian labor force
# 4                                     Employed
# ...                                        ...
# 98015                        18 years and over
# 98016                           18 to 64 years
# 98017                        65 years and over
# 98018                       People in families
# 98019  Unrelated individuals 15 years and over
#
#                                                 Category        State  \
# 0                                                 Header      Alabama
# 1                                      EMPLOYMENT STATUS      Alabama
# 2                                      EMPLOYMENT STATUS      Alabama
# 3                                      EMPLOYMENT STATUS      Alabama
# ...

# %%
acs_df['Label (Grouping)'] = acs_df['Label (Grouping)'].str.strip()

# %%
def get_header_indices(df):
    return df.index[df['Category'] == 'Header'].tolist()

header_indices = get_header_indices(acs_df)

split_dataframes = []

for i, start_index in enumerate(header_indices):
    if i < len(header_indices) - 1:
        end_index = header_indices[i + 1]
    else:
        end_index = len(acs_df)
    
    segment_df = acs_df[start_index:end_index]
    
    header_value = segment_df.iloc[0]['Label (Grouping)']
    
    segment_df = segment_df.drop(index=start_index).reset_index(drop=True)
    
    segment_df['Segment'] = header_value
    
    split_dataframes.append(segment_df)

split_df = pd.concat(split_dataframes).reset_index(drop=True)

split_df.head()
# Out:
#                Label (Grouping)           Category    State   Estimate  \
# 0  Population 16 years and over  EMPLOYMENT STATUS  Alabama  3,714,504
# 1                In labor force  EMPLOYMENT STATUS  Alabama  2,246,848
# 2          Civilian labor force  EMPLOYMENT STATUS  Alabama  2,230,879
# 3                      Employed  EMPLOYMENT STATUS  Alabama  2,036,867
# 4                    Unemployed  EMPLOYMENT STATUS  Alabama    194,012
#
#   Margin of Error    Percent Percent Margin of Error  Year            Segment
# 0          ±1,588  3,714,504                     (X)  2010  EMPLOYMENT STATUS
# 1          ±5,576      60.5%                    ±0.1  2010  EMPLOYMENT STATUS
# 2          ±5,531      60.1%                    ±0.1  2010  EMPLOYMENT STATUS
# 3          ±5,904      54.8%                    ±0.2  2010  EMPLOYMENT STATUS
# 4          ±3,179       5.2%                    ±0.1  2010  EMPLOYMENT STATUS

# %%
acs_dict = {}

# %%
unique_headers = list(acs_df[acs_df['Category'] == 'Header']['Label (Grouping)'].unique())
unique_headers
# Out:
# ['EMPLOYMENT STATUS',
#  'COMMUTING TO WORK',
#  'OCCUPATION',
#  'INDUSTRY',
#  'CLASS OF WORKER',
#  'INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#  'HEALTH INSURANCE COVERAGE',
#  'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL',
#  'INCOME AND BENEFITS (IN 2011 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2013 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2012 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2015 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)',
#  'INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)',
# ...

# %%
for header in unique_headers:
    acs_dict[header] = split_df[split_df['Segment'] == header]

# %%
acs_dict['COMMUTING TO WORK']
# Out:
#                                 Label (Grouping)           Category  \
# 17                     Workers 16 years and over  COMMUTING TO WORK
# 18             Car, truck, or van -- drove alone  COMMUTING TO WORK
# 19               Car, truck, or van -- carpooled  COMMUTING TO WORK
# 20     Public transportation (excluding taxicab)  COMMUTING TO WORK
# 21                                        Walked  COMMUTING TO WORK
# ...                                          ...                ...
# 92495  Public transportation (excluding taxicab)  COMMUTING TO WORK
# 92496                                     Walked  COMMUTING TO WORK
# 92497                                Other means  COMMUTING TO WORK
# 92498                           Worked from home  COMMUTING TO WORK
# 92499         Mean travel time to work (minutes)  COMMUTING TO WORK
#
#              State   Estimate Margin of Error    Percent  \
# 17         Alabama  2,000,289          ±6,235  2,000,289
# ...

# %%
obesity_df
# Out:
#         YearStart          LocationDesc                    Topic  \
# 1            2019               Arizona  Obesity / Weight Status
# 2            2019  District of Columbia  Obesity / Weight Status
# 4            2019              Maryland  Obesity / Weight Status
# 5            2011          Rhode Island  Obesity / Weight Status
# 6            2019               Montana  Obesity / Weight Status
# ...           ...                   ...                      ...
# 133339       2022               Wyoming  Obesity / Weight Status
# 133340       2022               Wyoming  Obesity / Weight Status
# 133342       2022               Wyoming  Obesity / Weight Status
# 133343       2022               Wyoming  Obesity / Weight Status
# 133344       2022               Wyoming  Obesity / Weight Status
#
#                                                  Question  Data_Value  \
# 1       Percent of students in grades 9-12 who have ob...        13.3
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Assuming obesity_df is your DataFrame

# Correct the extraction of latitude and longitude
# Ensure 'GeoLocation' is a string type and contains lat-long information
obesity_df['latitude'] = obesity_df['GeoLocation'].str.extract(r'\(([^,]+),')[0].astype(float)
obesity_df['longitude'] = obesity_df['GeoLocation'].str.extract(r',\s*([^)]+)\)')[0].astype(float)

# Convert your DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(obesity_df, geometry=gpd.points_from_xy(obesity_df.longitude, obesity_df.latitude))

# Load a map of the US. If you don't have one, Geopandas can load a low-resolution map for you.
us_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')).query('continent == "North America" and name == "United States of America"')

# Plotting with adjusted focus
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

us_map.plot(ax=ax, color='lightgrey', edgecolor='white')

# Plot each point from the GeoDataFrame onto the map
gdf.plot(ax=ax, column='Data_Value', cmap='Reds', markersize=10, legend=True, legend_kwds={'label': "Obesity Rate (%)"})

# Adjust these limits to zoom in on a specific area. Example values provided:
# Longitude limits
ax.set_xlim(-125, -66)
# Latitude limits
ax.set_ylim(24, 50)

plt.title('Zoomed Heatmap of Obesity Rates in the US')
plt.show()
# Out:
# /tmp/ipykernel_33/1842660130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_df['latitude'] = obesity_df['GeoLocation'].str.extract(r'\(([^,]+),')[0].astype(float)
# /tmp/ipykernel_33/1842660130.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesity_df['longitude'] = obesity_df['GeoLocation'].str.extract(r',\s*([^)]+)\)')[0].astype(float)
# ...

# %%
#genie_coefficient

# %%
stock_desc = pd.read_csv('/kaggle/input/asia-datathon-data/Datathon Data/stock_descriptions.csv')
stock_desc.head(31)
# Out:
#    Symbol     AssetType                                         Name  \
# 0     QSR  Common Stock          Restaurant Brands International Inc
# 1     ALG  Common Stock                              Alamo Group Inc
# 2    SBUX  Common Stock                        Starbucks Corporation
# 3     CAG  Common Stock                            ConAgra Foods Inc
# 4     HRL  Common Stock                     Hormel Foods Corporation
# 5     DPZ  Common Stock                           Domino’s Pizza Inc
# 6     CMG  Common Stock                   Chipotle Mexican Grill Inc
# 7     DRI  Common Stock                       Darden Restaurants Inc
# 8     GIS  Common Stock                            General Mills Inc
# 9    TSCO  Common Stock                       Tractor Supply Company
# 10    MCD  Common Stock                       McDonald’s Corporation
# 11    PPC  Common Stock                          Pilgrims Pride Corp
# 12    VMI  Common Stock                       Valmont Industries Inc
# ...

# %%
# Out:
#                                     Label (Grouping)  \
# 97830                      HEALTH INSURANCE COVERAGE
# 97831       Civilian noninstitutionalized population
# 97832                 With health insurance coverage
# 97833                  With private health insurance
# 97834                           With public coverage
# 97835                   No health insurance coverage
# 97837                   No health insurance coverage
# 97851                 With health insurance coverage
# 97852                  With private health insurance
# 97853                           With public coverage
# 97854                   No health insurance coverage
# 97975                      HEALTH INSURANCE COVERAGE
# 97976       Civilian noninstitutionalized population
# 97977                 With health insurance coverage
# 97978                  With private health insurance
# 97979                           With public coverage
# 97980                   No health insurance coverage
# ...

# %%
stock_desc.shape
# Out:
# (31, 6)

# %%
def merge_with_unique_cols(df_left, df_right, on_keys, suffixes=('_left', '_right')):
    df_right_renamed = df_right.rename(columns={
        col: f"{col}{suffixes[1]}" if col not in on_keys else col 
        for col in df_right.columns
    })
    return pd.merge(df_left, df_right_renamed, on=on_keys, how='outer')

industry_related_df = merge_with_unique_cols(meat_prod_df, cold_storage_df, on_keys=['Date', 'Year', 'Month'])
industry_related_df = merge_with_unique_cols(industry_related_df, sl_count_df, on_keys=['Date', 'Year', 'Month'])
industry_related_df = merge_with_unique_cols(industry_related_df, sl_weights_df, on_keys=['Date', 'Year', 'Month'])


industry_related_df

# %%
len(obesity_df['GeoLocation'].unique())

# %%
obesity_df.head()

# %%
obesity_df.iloc[0]['Question']
